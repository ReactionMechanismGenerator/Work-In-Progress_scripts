# %% [markdown]
# ## PDepPostProcessing
# Have a giant mechanism you couldn't get RMG to converge on when using
# PDep? Use this script to automatically divide your mechanism into sub
# networks, run each individually through RMG (and Cantherm), and
# unite them back into a single PDep mechanism.
# When running this notebook, make sure that RMG stops automatically
# after the first iteration and does not process new reactions,
# e.g., by checking out the PDepPost branch under alongd/RMG-Py on GitHub:
# https://github.com/alongd/RMG-Py/commits/PDepPost
#
# written by alongd

# %%
from rmgpy.data.kinetics.library import LibraryReaction, KineticsLibrary
from rmgpy.data.kinetics.database import KineticsDatabase
import os, shutil, re

# The library's name to be processed, name the new PDep-only library
libraryName = ['NG_HTP','NG_HTP_PDep']

# %%
# Load the library to be processed

database = KineticsDatabase()
basePath = '/home/alongd/Code/RMG-database/input/kinetics/libraries/' # path to 'RMG-database/input/kinetics/libraries/'

library_file = basePath+libraryName[0]+'/reactions.py'

library = KineticsLibrary(label=libraryName[0])
library.load(library_file, database.local_context, database.global_context)

# %%
# Create and save a new PDep-only library
PDepLibrary = KineticsLibrary(label=libraryName[1])

j = 0
for i, entry in library.entries.iteritems():
    if entry.item.isUnimolecular():
        j += 1
        PDepLibrary.entries[j] = library.entries[i]
        if len(PDepLibrary.entries[j].item.reactants) + len(PDepLibrary.entries[j].item.products) > 3: #assert unimolecular
            print "Error, {0} is not a unimolecular reaction".format(entry.label)

path = os.getcwd()
if not os.path.exists(path+'/output/'):
    os.makedirs(path+'/output/')
for the_file in os.listdir(path+'/output/'):
    file_path = os.path.join(path+'/output/', the_file)
    try:
        if os.path.isfile(file_path):
            os.unlink(file_path)
    except Exception as e:
        print(e)
PDepLibrary.save(path+'/output/output.py')

# %%
# functions

# Get a species and return all reactions in which it is in the mono side
def search(S):
    rxns = []
    for i, entry in PDepLibrary.entries.iteritems(): # entry = newLibrary.entries[i]
        if (S in entry.item.reactants and len(entry.item.reactants) == 1)\
            or (S in entry.item.products and len(entry.item.products) == 1):
            rxns.append(entry)
    return rxns

# decide which side in mono, and send to extractRxns()
def extractRxns(entry):
    if entry.item.isDissociation():
        rxns = search(entry.item.reactants[0])
    elif entry.item.isAssociation():
        rxns = search(entry.item.products[0])
    elif entry.item.isIsomerization():
        rxns = search(entry.item.reactants[0])
        rxns2 = search(entry.item.products[0])
        for r in rxns2:
            if not r in rxns:
                rxns.append(r)
    else:
        print "Error, reaction is niether Dissociation, Association, nor Isomerization"
    return rxns

# find isomerization reactions (other than the first reaction which was already explored)
def isomerization(rxns):
    isom = []
    for r in rxns:
        if r.item.isIsomerization() and r != rxns[0]:
            isom.append(r)
    return isom

def RMGlog(net):
    try:
        chem = open('runs/net'+str(net)+'/chemkin/chem_annotated.inp','r').readlines()
        lines = [x for x in chem[17:] if x != "\n"]
        readSpecies = False
        species = -2 # not counting CH4(1), O2(2)
        readRxns = False
        rxns = 0
        for line in lines:
            if "SPECIES" in line:
                readSpecies = True
            if "REACTIONS" in line:
                readRxns = True
            if "END" in line:
                readSpecies = readRxns = False
            if readSpecies:
                if '(' in line:
                    species += 1
            if readRxns:
                if 'Reaction index' in line:
                    rxns += 1
        print("Done simulating net{0} with {1} species and {2} reactions.\n".format(net,species,rxns))
    except:
        return 1
    return 0

def createInputFile(net):
    cwd = os.getcwd()
    if not os.path.exists(cwd+'/runs/'):
        os.mkdir(cwd+'/runs/')
    if not os.path.exists(cwd+'/runs/net{0}/'.format(net)):
        os.mkdir(cwd+'/runs/net{0}/'.format(net))

    inputFile = '''
database(
    thermoLibraries = ['BurkeH2O2','primaryThermoLibrary','NG_HTP','Chernov','Narayanaswamy'],
    reactionLibraries = [],
    seedMechanisms = ['networks/net'''+str(net)+''''],
    kineticsDepositories = [],
    kineticsFamilies = 'default',
    kineticsEstimator = 'rate rules',
)

species(
    label='CH4',
    reactive=True,
    structure=SMILES('C'),
)

species(
    label='O2',
    reactive=True,
    structure=SMILES('[O][O]'),
)


species(
    label='Ar',
    reactive=False,
    structure=adjacencyList(
                """
                1 Ar u0 p4 c0
                """),
)

simpleReactor(
    temperature=(2000,'K'),
    pressure=(1,'atm'),
    initialMoleFractions={
        "CH4": 0.015,
        "O2": 0.02,
        "Ar": 0.9,
    },
    terminationTime=(0.001,'s'),
)

simulator(
    atol=1e-16,
    rtol=1e-8,
)

model(
    toleranceKeepInEdge=0,
    toleranceMoveToCore=0.05,
    toleranceInterruptSimulation=0.05,
    maximumEdgeSpecies=300000
)

pressureDependence(
        method='modified strong collision',
        maximumGrainSize=(0.5,'kcal/mol'),
        minimumNumberOfGrains=250,
        temperatures=(1600,2200,'K',10),
        pressures=(0.5,1.5,'bar',5),
        interpolation=('Chebyshev', 6, 4),
        maximumAtoms=16,
)

options(
    units='si',
    generateOutputHTML=False,
    generatePlots=False,
    saveEdgeSpecies=False,
    saveSimulationProfiles=False,
    saveRestartPeriod=None,
)

generatedSpeciesConstraints(
    allowed=['input species','seed mechanisms','reaction libraries'],
    maximumCarbonAtoms=10,
    maximumOxygenAtoms=10,
    maximumNitrogenAtoms=0,
    maximumSiliconAtoms=0,
    maximumSulfurAtoms=0,
    maximumHeavyAtoms=15,
    maximumRadicalElectrons=1,
    allowSingletO2=False,
)

'''
    path = cwd+'/runs/net{0}/input.py'.format(net)
    with open(path,'w') as RMGInputFile:
        RMGInputFile.write(inputFile)
    return

# %%
# Extract the different sub-PDep-networks

path = basePath+'networks/'
if os.path.exists(path):
    shutil.rmtree(path) # delete 'networks' tree if exists
os.makedirs(path)

networks = [] # an array of KineticsLibrary objects
net = 0 # network counter
processed = []
proc = 0 # processed counter

for i, entry in PDepLibrary.entries.iteritems(): # entry = PDepLibrary.entries[i]
    if entry not in processed:
        rxns = extractRxns(entry)

    stillIsomerization = 1
    while stillIsomerization: # continue untill no unexplored isomerization reactions are left in the network
        isom = isomerization(rxns)
        rxns3 = []
        for iso in isom:
            rxns3 = extractRxns(iso)
        stillIsomerization = 0
        for k in rxns3:
            if k.item.isIsomerization(): stillIsomerization == 1
            if k not in processed and k not in rxns:
                rxns.append(k)
                
    if entry not in processed:
        net += 1
        j = 0
        network = KineticsLibrary(label='network {0}'.format(net))
        for r in rxns:
            if r not in processed:
                proc += 1
                processed.append(r)
            j += 1
            network.entries[j] = r
        network.save(path+'/net{0}/reactions.py'.format(net))
        library_dictionary = basePath+libraryName[0]+'/dictionary.txt'
        shutil.copyfile(library_dictionary, path+'/net{0}/dictionary.txt'.format(net))
    for r in rxns:
        if r not in processed:
            proc += 1
            processed.append(r)

print "Done.\nProcessed {0} rxns, saved {1} independent networks.".format(len(processed),net)
# Out:
# Done.
# Processed 1719 rxns, saved 406 independent networks.

# %% [markdown]
# ## run RMG
# Careful, this will delete previous runs!!

# %%
import os, shutil, time

#net=406
#n=12-1

t0 = time.time()
cwd = os.getcwd()
if os.path.exists(cwd+'/runs/'):
    shutil.rmtree(cwd+'/runs/') # delete 'runs' tree if exists

errored = []
for n in xrange(net):
    network = n + 1
    print("Simulating net{0}...".format(network))
    try:
        createInputFile(network)
        os.system('python $rmg/rmg.py runs/net'+str(network)+'/input.py')
        if not os.path.exists(cwd+'/runs/net'+str(network)+'/chemkin/'):
            ok = False
            while not ok:
                time.sleep(5)
                if os.path.exists(cwd+'/runs/net'+str(network)+'/chemkin/'):
                    ok = True
        e = RMGlog(network)
        if e == 1:
            errored.append(network)
            print("ERROR reading net{0}!".format(network))
    except:
        pass

if len(errored) > 0: # print an error summary
    for e in errored:
        print("ERROR in network {0}!".format(network))

t1 = time.time() - t0
m, s = divmod(t1, 60)
h, m = divmod(m, 60)
#d, h = divmod(h, 24)
#print('\nTotal elapsed time: %02d %02d:%02d:%02d'%(d, h, m, s))
print('\nTotal elapsed time: %02d:%02d:%02d'%(h, m, s))
print('\n\n***\nAll Done.\n***')
# Out:
# Simulating net1...
# Done simulating net1 with 2 species and 1 reactions.
#
# Simulating net2...
# Done simulating net2 with 1 species and 1 reactions.
#
# Simulating net3...
# Done simulating net3 with 3 species and 1 reactions.
#
# Simulating net4...
# Done simulating net4 with 3 species and 1 reactions.
#
# Simulating net5...
# Done simulating net5 with 4 species and 3 reactions.
#
# Simulating net6...
# Done simulating net6 with 4 species and 3 reactions.
#
# Simulating net7...
# Done simulating net7 with 3 species and 1 reactions.
#
# Simulating net8...
# Done simulating net8 with 11 species and 10 reactions.
#
# Simulating net9...
# Done simulating net9 with 4 species and 3 reactions.
#
# Simulating net10...
# Done simulating net10 with 5 species and 4 reactions.
#
# Simulating net11...
# Done simulating net11 with 8 species and 8 reactions.
#
# Simulating net12...
# Done simulating net12 with 11 species and 8 reactions.
#
# Simulating net13...
# Done simulating net13 with 7 species and 4 reactions.
#
# Simulating net14...
# Done simulating net14 with 11 species and 8 reactions.
#
# Simulating net15...
# Done simulating net15 with 3 species and 1 reactions.
#
# Simulating net16...
# Done simulating net16 with 7 species and 5 reactions.
#
# Simulating net17...
# Done simulating net17 with 10 species and 12 reactions.
#
# Simulating net18...
# Done simulating net18 with 13 species and 15 reactions.
#
# Simulating net19...
# Done simulating net19 with 4 species and 2 reactions.
#
# Simulating net20...
# Done simulating net20 with 8 species and 10 reactions.
#
# Simulating net21...
# Done simulating net21 with 5 species and 3 reactions.
#
# Simulating net22...
# Done simulating net22 with 6 species and 5 reactions.
#
# Simulating net23...
# Done simulating net23 with 3 species and 1 reactions.
#
# Simulating net24...
# Done simulating net24 with 3 species and 1 reactions.
#
# Simulating net25...
# Done simulating net25 with 3 species and 1 reactions.
#
# Simulating net26...
# Done simulating net26 with 12 species and 12 reactions.
#
# Simulating net27...
# Done simulating net27 with 3 species and 1 reactions.
#
# Simulating net28...
# Done simulating net28 with 5 species and 3 reactions.
#
# Simulating net29...
# Done simulating net29 with 5 species and 3 reactions.
#
# Simulating net30...
# Done simulating net30 with 10 species and 11 reactions.
#
# Simulating net31...
# Done simulating net31 with 11 species and 12 reactions.
#
# Simulating net32...
# Done simulating net32 with 10 species and 11 reactions.
#
# Simulating net33...
# Done simulating net33 with 11 species and 8 reactions.
#
# Simulating net34...
# Done simulating net34 with 5 species and 3 reactions.
#
# Simulating net35...
# Done simulating net35 with 3 species and 1 reactions.
#
# Simulating net36...
# Done simulating net36 with 7 species and 6 reactions.
#
# Simulating net37...
# Done simulating net37 with 11 species and 12 reactions.
#
# Simulating net38...
# Done simulating net38 with 3 species and 2 reactions.
#
# Simulating net39...
# Done simulating net39 with 5 species and 3 reactions.
#
# Simulating net40...
# Done simulating net40 with 8 species and 6 reactions.
#
# Simulating net41...
# Done simulating net41 with 6 species and 7 reactions.
#
# Simulating net42...
# Done simulating net42 with 8 species and 7 reactions.
#
# Simulating net43...
# Done simulating net43 with 5 species and 3 reactions.
#
# Simulating net44...
# Done simulating net44 with 10 species and 11 reactions.
#
# Simulating net45...
# Done simulating net45 with 8 species and 8 reactions.
#
# Simulating net46...
# Done simulating net46 with 3 species and 2 reactions.
#
# Simulating net47...
# Done simulating net47 with 4 species and 3 reactions.
#
# Simulating net48...
# Done simulating net48 with 4 species and 2 reactions.
#
# Simulating net49...
# Done simulating net49 with 4 species and 3 reactions.
#
# Simulating net50...
# Done simulating net50 with 9 species and 6 reactions.
#
# Simulating net51...
# Done simulating net51 with 4 species and 2 reactions.
#
# Simulating net52...
# Done simulating net52 with 3 species and 2 reactions.
#
# Simulating net53...
# Done simulating net53 with 14 species and 22 reactions.
#
# Simulating net54...
# Done simulating net54 with 11 species and 13 reactions.
#
# Simulating net55...
# Done simulating net55 with 9 species and 14 reactions.
#
# Simulating net56...
# Done simulating net56 with 10 species and 10 reactions.
#
# Simulating net57...
# Done simulating net57 with 9 species and 9 reactions.
#
# Simulating net58...
# Done simulating net58 with 12 species and 19 reactions.
#
# Simulating net59...
# Done simulating net59 with 14 species and 13 reactions.
#
# Simulating net60...
# Done simulating net60 with 4 species and 2 reactions.
#
# Simulating net61...
# Done simulating net61 with 9 species and 6 reactions.
#
# Simulating net62...
# Done simulating net62 with 11 species and 7 reactions.
#
# Simulating net63...
# Done simulating net63 with 8 species and 8 reactions.
#
# Simulating net64...
# Done simulating net64 with 8 species and 13 reactions.
#
# Simulating net65...
# Done simulating net65 with 9 species and 14 reactions.
#
# Simulating net66...
# Done simulating net66 with 9 species and 7 reactions.
#
# Simulating net67...
# Done simulating net67 with 3 species and 1 reactions.
#
# Simulating net68...
# Done simulating net68 with 8 species and 7 reactions.
#
# Simulating net69...
# Done simulating net69 with 8 species and 7 reactions.
#
# Simulating net70...
# Done simulating net70 with 7 species and 6 reactions.
#
# Simulating net71...
# Done simulating net71 with 7 species and 7 reactions.
#
# Simulating net72...
# Done simulating net72 with 5 species and 2 reactions.
#
# Simulating net73...
# Done simulating net73 with 8 species and 6 reactions.
#
# Simulating net74...
# Done simulating net74 with 7 species and 6 reactions.
#
# Simulating net75...
# Done simulating net75 with 11 species and 10 reactions.
#
# Simulating net76...
# Done simulating net76 with 11 species and 10 reactions.
#
# Simulating net77...
# Done simulating net77 with 3 species and 1 reactions.
#
# Simulating net78...
# Done simulating net78 with 7 species and 5 reactions.
#
# Simulating net79...
# Done simulating net79 with 4 species and 3 reactions.
#
# Simulating net80...
# Done simulating net80 with 5 species and 6 reactions.
#
# Simulating net81...
# Done simulating net81 with 9 species and 10 reactions.
#
# Simulating net82...
# Done simulating net82 with 6 species and 5 reactions.
#
# Simulating net83...
# Done simulating net83 with 5 species and 4 reactions.
#
# Simulating net84...
# Done simulating net84 with 3 species and 0 reactions.
#
# Simulating net85...
# Done simulating net85 with 14 species and 12 reactions.
#
# Simulating net86...
# Done simulating net86 with 7 species and 3 reactions.
#
# Simulating net87...
# Done simulating net87 with 8 species and 6 reactions.
#
# Simulating net88...
# Done simulating net88 with 10 species and 10 reactions.
#
# Simulating net89...
# Done simulating net89 with 6 species and 4 reactions.
#
# Simulating net90...
# Done simulating net90 with 3 species and 2 reactions.
#
# Simulating net91...
# Done simulating net91 with 8 species and 10 reactions.
#
# Simulating net92...
# Done simulating net92 with 5 species and 4 reactions.
#
# Simulating net93...
# Done simulating net93 with 5 species and 4 reactions.
#
# Simulating net94...
# Done simulating net94 with 8 species and 6 reactions.
#
# Simulating net95...
# Done simulating net95 with 5 species and 2 reactions.
#
# Simulating net96...
# Done simulating net96 with 8 species and 7 reactions.
#
# Simulating net97...
# Done simulating net97 with 2 species and 1 reactions.
#
# Simulating net98...
# Done simulating net98 with 5 species and 2 reactions.
#
# Simulating net99...
# Done simulating net99 with 13 species and 13 reactions.
#
# Simulating net100...
# Done simulating net100 with 2 species and 1 reactions.
#
# Simulating net101...
# Done simulating net101 with 6 species and 5 reactions.
#
# Simulating net102...
# Done simulating net102 with 3 species and 1 reactions.
#
# Simulating net103...
# Done simulating net103 with 12 species and 9 reactions.
#
# Simulating net104...
# Done simulating net104 with 9 species and 8 reactions.
#
# Simulating net105...
# Done simulating net105 with 13 species and 12 reactions.
#
# Simulating net106...
# Done simulating net106 with 12 species and 9 reactions.
#
# Simulating net107...
# Done simulating net107 with 7 species and 6 reactions.
#
# Simulating net108...
# Done simulating net108 with 6 species and 3 reactions.
#
# Simulating net109...
# Done simulating net109 with 8 species and 7 reactions.
#
# Simulating net110...
# Done simulating net110 with 3 species and 3 reactions.
#
# Simulating net111...
# Done simulating net111 with 2 species and 1 reactions.
#
# Simulating net112...
# Done simulating net112 with 5 species and 5 reactions.
#
# Simulating net113...
# Done simulating net113 with 5 species and 5 reactions.
#
# Simulating net114...
# Done simulating net114 with 8 species and 8 reactions.
#
# Simulating net115...
# Done simulating net115 with 11 species and 8 reactions.
#
# Simulating net116...
# Done simulating net116 with 4 species and 3 reactions.
#
# Simulating net117...
# Done simulating net117 with 8 species and 6 reactions.
#
# Simulating net118...
# Done simulating net118 with 5 species and 3 reactions.
#
# Simulating net119...
# Done simulating net119 with 3 species and 1 reactions.
#
# Simulating net120...
# Done simulating net120 with 7 species and 6 reactions.
#
# Simulating net121...
# Done simulating net121 with 7 species and 8 reactions.
#
# Simulating net122...
# Done simulating net122 with 12 species and 20 reactions.
#
# Simulating net123...
# Done simulating net123 with 7 species and 9 reactions.
#
# Simulating net124...
# Done simulating net124 with 9 species and 8 reactions.
#
# Simulating net125...
# Done simulating net125 with 7 species and 7 reactions.
#
# Simulating net126...
# Done simulating net126 with 10 species and 16 reactions.
#
# Simulating net127...
# Done simulating net127 with 7 species and 7 reactions.
#
# Simulating net128...
# Done simulating net128 with 7 species and 5 reactions.
#
# Simulating net129...
# Done simulating net129 with 9 species and 12 reactions.
#
# Simulating net130...
# Done simulating net130 with 7 species and 7 reactions.
#
# Simulating net131...
# Done simulating net131 with 4 species and 3 reactions.
#
# Simulating net132...
# Done simulating net132 with 6 species and 8 reactions.
#
# Simulating net133...
# Done simulating net133 with 4 species and 3 reactions.
#
# Simulating net134...
# Done simulating net134 with 8 species and 9 reactions.
#
# Simulating net135...
# Done simulating net135 with 7 species and 7 reactions.
#
# Simulating net136...
# Done simulating net136 with 10 species and 11 reactions.
#
# Simulating net137...
# Done simulating net137 with 5 species and 4 reactions.
#
# Simulating net138...
# Done simulating net138 with 7 species and 8 reactions.
#
# Simulating net139...
# Done simulating net139 with 6 species and 6 reactions.
#
# Simulating net140...
# Done simulating net140 with 5 species and 5 reactions.
#
# Simulating net141...
# Done simulating net141 with 7 species and 7 reactions.
#
# Simulating net142...
# Done simulating net142 with 2 species and 1 reactions.
#
# Simulating net143...
# Done simulating net143 with 5 species and 4 reactions.
#
# Simulating net144...
# Done simulating net144 with 7 species and 7 reactions.
#
# Simulating net145...
# Done simulating net145 with 9 species and 7 reactions.
#
# Simulating net146...
# Done simulating net146 with 7 species and 12 reactions.
#
# Simulating net147...
# Done simulating net147 with 5 species and 4 reactions.
#
# Simulating net148...
# Done simulating net148 with 7 species and 8 reactions.
#
# Simulating net149...
# Done simulating net149 with 6 species and 6 reactions.
#
# Simulating net150...
# Done simulating net150 with 4 species and 4 reactions.
#
# Simulating net151...
# Done simulating net151 with 8 species and 6 reactions.
#
# Simulating net152...
# Done simulating net152 with 8 species and 8 reactions.
#
# Simulating net153...
# Done simulating net153 with 4 species and 3 reactions.
#
# Simulating net154...
# Done simulating net154 with 8 species and 6 reactions.
#
# Simulating net155...
# Done simulating net155 with 3 species and 2 reactions.
#
# Simulating net156...
# Done simulating net156 with 4 species and 3 reactions.
#
# Simulating net157...
# Done simulating net157 with 5 species and 6 reactions.
#
# Simulating net158...
# Done simulating net158 with 6 species and 10 reactions.
#
# Simulating net159...
# Done simulating net159 with 4 species and 4 reactions.
#
# Simulating net160...
# Done simulating net160 with 8 species and 16 reactions.
#
# Simulating net161...
# Done simulating net161 with 7 species and 11 reactions.
#
# Simulating net162...
# Done simulating net162 with 5 species and 6 reactions.
#
# Simulating net163...
# Done simulating net163 with 2 species and 1 reactions.
#
# Simulating net164...
# Done simulating net164 with 5 species and 2 reactions.
#
# Simulating net165...
# Done simulating net165 with 3 species and 0 reactions.
#
# Simulating net166...
# Done simulating net166 with 5 species and 2 reactions.
#
# Simulating net167...
# Done simulating net167 with 3 species and 1 reactions.
#
# Simulating net168...
# Done simulating net168 with 5 species and 2 reactions.
#
# Simulating net169...
# Done simulating net169 with 7 species and 8 reactions.
#
# Simulating net170...
# Done simulating net170 with 7 species and 4 reactions.
#
# Simulating net171...
# Done simulating net171 with 3 species and 1 reactions.
#
# Simulating net172...
# Done simulating net172 with 9 species and 7 reactions.
#
# Simulating net173...
# Done simulating net173 with 2 species and 1 reactions.
#
# Simulating net174...
# Done simulating net174 with 9 species and 9 reactions.
#
# Simulating net175...
# Done simulating net175 with 10 species and 8 reactions.
#
# Simulating net176...
# Done simulating net176 with 10 species and 7 reactions.
#
# Simulating net177...
# Done simulating net177 with 7 species and 5 reactions.
#
# Simulating net178...
# Done simulating net178 with 3 species and 1 reactions.
#
# Simulating net179...
# Done simulating net179 with 3 species and 1 reactions.
#
# Simulating net180...
# Done simulating net180 with 6 species and 3 reactions.
#
# Simulating net181...
# Done simulating net181 with 7 species and 4 reactions.
#
# Simulating net182...
# Done simulating net182 with 3 species and 1 reactions.
#
# Simulating net183...
# Done simulating net183 with 6 species and 7 reactions.
#
# Simulating net184...
# Done simulating net184 with 8 species and 5 reactions.
#
# Simulating net185...
# Done simulating net185 with 5 species and 3 reactions.
#
# Simulating net186...
# Done simulating net186 with 5 species and 2 reactions.
#
# Simulating net187...
# Done simulating net187 with 9 species and 6 reactions.
#
# Simulating net188...
# Done simulating net188 with 3 species and 1 reactions.
#
# Simulating net189...
# Done simulating net189 with 3 species and 1 reactions.
#
# Simulating net190...
# Done simulating net190 with 3 species and 1 reactions.
#
# Simulating net191...
# Done simulating net191 with 3 species and 1 reactions.
#
# Simulating net192...
# Done simulating net192 with 6 species and 5 reactions.
#
# Simulating net193...
# Done simulating net193 with 3 species and 1 reactions.
#
# Simulating net194...
# Done simulating net194 with 3 species and 1 reactions.
#
# Simulating net195...
# Done simulating net195 with 7 species and 6 reactions.
#
# Simulating net196...
# Done simulating net196 with 5 species and 2 reactions.
#
# Simulating net197...
# Done simulating net197 with 5 species and 1 reactions.
#
# Simulating net198...
# Done simulating net198 with 12 species and 12 reactions.
#
# Simulating net199...
# Done simulating net199 with 8 species and 6 reactions.
#
# Simulating net200...
# Done simulating net200 with 2 species and 1 reactions.
#
# Simulating net201...
# Done simulating net201 with 3 species and 3 reactions.
#
# Simulating net202...
# Done simulating net202 with 5 species and 2 reactions.
#
# Simulating net203...
# Done simulating net203 with 3 species and 1 reactions.
#
# Simulating net204...
# Done simulating net204 with 5 species and 2 reactions.
#
# Simulating net205...
# Done simulating net205 with 10 species and 11 reactions.
#
# Simulating net206...
# Done simulating net206 with 12 species and 13 reactions.
#
# Simulating net207...
# Done simulating net207 with 7 species and 4 reactions.
#
# Simulating net208...
# Done simulating net208 with 4 species and 2 reactions.
#
# Simulating net209...
# Done simulating net209 with 3 species and 0 reactions.
#
# Simulating net210...
# Done simulating net210 with 5 species and 3 reactions.
#
# Simulating net211...
# Done simulating net211 with 9 species and 9 reactions.
#
# Simulating net212...
# Done simulating net212 with 3 species and 1 reactions.
#
# Simulating net213...
# Done simulating net213 with 3 species and 1 reactions.
#
# Simulating net214...
# Done simulating net214 with 2 species and 1 reactions.
#
# Simulating net215...
# Done simulating net215 with 5 species and 2 reactions.
#
# Simulating net216...
# Done simulating net216 with 2 species and 1 reactions.
#
# Simulating net217...
# Done simulating net217 with 3 species and 1 reactions.
#
# Simulating net218...
# Done simulating net218 with 3 species and 1 reactions.
#
# Simulating net219...
# Done simulating net219 with 3 species and 1 reactions.
#
# Simulating net220...
# Done simulating net220 with 4 species and 2 reactions.
#
# Simulating net221...
# Done simulating net221 with 12 species and 11 reactions.
#
# Simulating net222...
# Done simulating net222 with 12 species and 9 reactions.
#
# Simulating net223...
# Done simulating net223 with 11 species and 11 reactions.
#
# Simulating net224...
# Done simulating net224 with 3 species and 1 reactions.
#
# Simulating net225...
# Done simulating net225 with 7 species and 3 reactions.
#
# Simulating net226...
# Done simulating net226 with 5 species and 2 reactions.
#
# Simulating net227...
# Done simulating net227 with 3 species and 1 reactions.
#
# Simulating net228...
# Done simulating net228 with 9 species and 4 reactions.
#
# Simulating net229...
# Done simulating net229 with 4 species and 2 reactions.
#
# Simulating net230...
# Done simulating net230 with 4 species and 2 reactions.
#
# Simulating net231...
# Done simulating net231 with 8 species and 5 reactions.
#
# Simulating net232...
# Done simulating net232 with 8 species and 7 reactions.
#
# Simulating net233...
# Done simulating net233 with 2 species and 1 reactions.
#
# Simulating net234...
# Done simulating net234 with 4 species and 3 reactions.
#
# Simulating net235...
# Done simulating net235 with 4 species and 3 reactions.
#
# Simulating net236...
# Done simulating net236 with 2 species and 1 reactions.
#
# Simulating net237...
# Done simulating net237 with 8 species and 7 reactions.
#
# Simulating net238...
# Done simulating net238 with 2 species and 1 reactions.
#
# Simulating net239...
# Done simulating net239 with 9 species and 7 reactions.
#
# Simulating net240...
# Done simulating net240 with 2 species and 1 reactions.
#
# Simulating net241...
# Done simulating net241 with 8 species and 8 reactions.
#
# Simulating net242...
# Done simulating net242 with 6 species and 4 reactions.
#
# Simulating net243...
# Done simulating net243 with 5 species and 2 reactions.
#
# Simulating net244...
# Done simulating net244 with 7 species and 5 reactions.
#
# Simulating net245...
# Done simulating net245 with 4 species and 2 reactions.
#
# Simulating net246...
# Done simulating net246 with 3 species and 1 reactions.
#
# Simulating net247...
# Done simulating net247 with 3 species and 1 reactions.
#
# Simulating net248...
# Done simulating net248 with 7 species and 2 reactions.
#
# Simulating net249...
# Done simulating net249 with 12 species and 11 reactions.
#
# Simulating net250...
# Done simulating net250 with 3 species and 1 reactions.
#
# Simulating net251...
# Done simulating net251 with 4 species and 2 reactions.
#
# Simulating net252...
# Done simulating net252 with 4 species and 2 reactions.
#
# Simulating net253...
# Done simulating net253 with 6 species and 8 reactions.
#
# Simulating net254...
# Done simulating net254 with 5 species and 4 reactions.
#
# Simulating net255...
# Done simulating net255 with 5 species and 1 reactions.
#
# Simulating net256...
# Done simulating net256 with 5 species and 4 reactions.
#
# Simulating net257...
# Done simulating net257 with 2 species and 1 reactions.
#
# Simulating net258...
# Done simulating net258 with 8 species and 10 reactions.
#
# Simulating net259...
# Done simulating net259 with 2 species and 1 reactions.
#
# Simulating net260...
# Done simulating net260 with 5 species and 6 reactions.
#
# Simulating net261...
# Done simulating net261 with 2 species and 1 reactions.
#
# Simulating net262...
# Done simulating net262 with 4 species and 2 reactions.
#
# Simulating net263...
# Done simulating net263 with 7 species and 5 reactions.
#
# Simulating net264...
# Done simulating net264 with 4 species and 2 reactions.
#
# Simulating net265...
# Done simulating net265 with 10 species and 17 reactions.
#
# Simulating net266...
# Done simulating net266 with 5 species and 2 reactions.
#
# Simulating net267...
# Done simulating net267 with 4 species and 2 reactions.
#
# Simulating net268...
# Done simulating net268 with 3 species and 1 reactions.
#
# Simulating net269...
# Done simulating net269 with 7 species and 5 reactions.
#
# Simulating net270...
# Done simulating net270 with 2 species and 1 reactions.
#
# Simulating net271...
# Done simulating net271 with 2 species and 1 reactions.
#
# Simulating net272...
# Done simulating net272 with 5 species and 4 reactions.
#
# Simulating net273...
# Done simulating net273 with 3 species and 2 reactions.
#
# Simulating net274...
# Done simulating net274 with 8 species and 6 reactions.
#
# Simulating net275...
# Done simulating net275 with 7 species and 6 reactions.
#
# Simulating net276...
# Done simulating net276 with 6 species and 3 reactions.
#
# Simulating net277...
# Done simulating net277 with 14 species and 22 reactions.
#
# Simulating net278...
# Done simulating net278 with 15 species and 21 reactions.
#
# Simulating net279...
# Done simulating net279 with 9 species and 11 reactions.
#
# Simulating net280...
# Done simulating net280 with 6 species and 6 reactions.
#
# Simulating net281...
# Done simulating net281 with 5 species and 4 reactions.
#
# Simulating net282...
# Done simulating net282 with 5 species and 4 reactions.
#
# Simulating net283...
# Done simulating net283 with 9 species and 9 reactions.
#
# Simulating net284...
# Done simulating net284 with 10 species and 10 reactions.
#
# Simulating net285...
# Done simulating net285 with 6 species and 3 reactions.
#
# Simulating net286...
# Done simulating net286 with 12 species and 16 reactions.
#
# Simulating net287...
# Done simulating net287 with 8 species and 7 reactions.
#
# Simulating net288...
# Done simulating net288 with 8 species and 8 reactions.
#
# Simulating net289...
# Done simulating net289 with 3 species and 1 reactions.
#
# Simulating net290...
# Done simulating net290 with 4 species and 2 reactions.
#
# Simulating net291...
# Done simulating net291 with 3 species and 1 reactions.
#
# Simulating net292...
# Done simulating net292 with 5 species and 2 reactions.
#
# Simulating net293...
# Done simulating net293 with 3 species and 1 reactions.
#
# Simulating net294...
# Done simulating net294 with 5 species and 3 reactions.
#
# Simulating net295...
# Done simulating net295 with 3 species and 1 reactions.
#
# Simulating net296...
# Done simulating net296 with 2 species and 1 reactions.
#
# Simulating net297...
# Done simulating net297 with 2 species and 1 reactions.
#
# Simulating net298...
# Done simulating net298 with 2 species and 1 reactions.
#
# Simulating net299...
# Done simulating net299 with 2 species and 1 reactions.
#
# Simulating net300...
# Done simulating net300 with 3 species and 0 reactions.
#
# Simulating net301...
# Done simulating net301 with 5 species and 4 reactions.
#
# Simulating net302...
# Done simulating net302 with 3 species and 1 reactions.
#
# Simulating net303...
# Done simulating net303 with 3 species and 1 reactions.
#
# Simulating net304...
# Done simulating net304 with 10 species and 10 reactions.
#
# Simulating net305...
# Done simulating net305 with 6 species and 3 reactions.
#
# Simulating net306...
# Done simulating net306 with 6 species and 4 reactions.
#
# Simulating net307...
# Done simulating net307 with 8 species and 6 reactions.
#
# Simulating net308...
# Done simulating net308 with 5 species and 3 reactions.
#
# Simulating net309...
# Done simulating net309 with 4 species and 2 reactions.
#
# Simulating net310...
# Done simulating net310 with 11 species and 12 reactions.
#
# Simulating net311...
# Done simulating net311 with 9 species and 9 reactions.
#
# Simulating net312...
# Done simulating net312 with 11 species and 9 reactions.
#
# Simulating net313...
# Done simulating net313 with 9 species and 11 reactions.
#
# Simulating net314...
# Done simulating net314 with 3 species and 1 reactions.
#
# Simulating net315...
# Done simulating net315 with 4 species and 3 reactions.
#
# Simulating net316...
# Done simulating net316 with 5 species and 2 reactions.
#
# Simulating net317...
# Done simulating net317 with 6 species and 4 reactions.
#
# Simulating net318...
# Done simulating net318 with 5 species and 2 reactions.
#
# Simulating net319...
# Done simulating net319 with 6 species and 3 reactions.
#
# Simulating net320...
# Done simulating net320 with 9 species and 6 reactions.
#
# Simulating net321...
# Done simulating net321 with 10 species and 12 reactions.
#
# Simulating net322...
# Done simulating net322 with 4 species and 3 reactions.
#
# Simulating net323...
# Done simulating net323 with 6 species and 3 reactions.
#
# Simulating net324...
# Done simulating net324 with 6 species and 3 reactions.
#
# Simulating net325...
# Done simulating net325 with 11 species and 7 reactions.
#
# Simulating net326...
# Done simulating net326 with 5 species and 2 reactions.
#
# Simulating net327...
# Done simulating net327 with 2 species and 1 reactions.
#
# Simulating net328...
# Done simulating net328 with 5 species and 2 reactions.
#
# Simulating net329...
# Done simulating net329 with 5 species and 2 reactions.
#
# Simulating net330...
# Done simulating net330 with 3 species and 3 reactions.
#
# Simulating net331...
# Done simulating net331 with 12 species and 16 reactions.
#
# Simulating net332...
# Done simulating net332 with 7 species and 3 reactions.
#
# Simulating net333...
# Done simulating net333 with 8 species and 7 reactions.
#
# Simulating net334...
# Done simulating net334 with 8 species and 8 reactions.
#
# Simulating net335...
# Done simulating net335 with 9 species and 9 reactions.
#
# Simulating net336...
# Done simulating net336 with 12 species and 12 reactions.
#
# Simulating net337...
# Done simulating net337 with 9 species and 9 reactions.
#
# Simulating net338...
# Done simulating net338 with 8 species and 7 reactions.
#
# Simulating net339...
# Done simulating net339 with 8 species and 7 reactions.
#
# Simulating net340...
# Done simulating net340 with 12 species and 16 reactions.
#
# Simulating net341...
# Done simulating net341 with 10 species and 10 reactions.
#
# Simulating net342...
# Done simulating net342 with 3 species and 1 reactions.
#
# Simulating net343...
# Done simulating net343 with 13 species and 16 reactions.
#
# Simulating net344...
# Done simulating net344 with 12 species and 10 reactions.
#
# Simulating net345...
# Done simulating net345 with 6 species and 4 reactions.
#
# Simulating net346...
# Done simulating net346 with 3 species and 2 reactions.
#
# Simulating net347...
# Done simulating net347 with 7 species and 4 reactions.
#
# Simulating net348...
# Done simulating net348 with 7 species and 6 reactions.
#
# Simulating net349...
# Done simulating net349 with 6 species and 4 reactions.
#
# Simulating net350...
# Done simulating net350 with 8 species and 7 reactions.
#
# Simulating net351...
# Done simulating net351 with 10 species and 8 reactions.
#
# Simulating net352...
# Done simulating net352 with 8 species and 5 reactions.
#
# Simulating net353...
# Done simulating net353 with 8 species and 6 reactions.
#
# Simulating net354...
# Done simulating net354 with 6 species and 4 reactions.
#
# Simulating net355...
# Done simulating net355 with 4 species and 2 reactions.
#
# Simulating net356...
# Done simulating net356 with 5 species and 4 reactions.
#
# Simulating net357...
# Done simulating net357 with 7 species and 6 reactions.
#
# Simulating net358...
# Done simulating net358 with 7 species and 4 reactions.
#
# Simulating net359...
# Done simulating net359 with 6 species and 3 reactions.
#
# Simulating net360...
# Done simulating net360 with 6 species and 3 reactions.
#
# Simulating net361...
# Done simulating net361 with 6 species and 3 reactions.
#
# Simulating net362...
# Done simulating net362 with 6 species and 3 reactions.
#
# Simulating net363...
# Done simulating net363 with 4 species and 2 reactions.
#
# Simulating net364...
# Done simulating net364 with 6 species and 4 reactions.
#
# Simulating net365...
# Done simulating net365 with 5 species and 4 reactions.
#
# Simulating net366...
# Done simulating net366 with 15 species and 13 reactions.
#
# Simulating net367...
# Done simulating net367 with 6 species and 4 reactions.
#
# Simulating net368...
# Done simulating net368 with 6 species and 6 reactions.
#
# Simulating net369...
# Done simulating net369 with 8 species and 7 reactions.
#
# Simulating net370...
# Done simulating net370 with 9 species and 9 reactions.
#
# Simulating net371...
# Done simulating net371 with 6 species and 5 reactions.
#
# Simulating net372...
# Done simulating net372 with 4 species and 2 reactions.
#
# Simulating net373...
# Done simulating net373 with 7 species and 6 reactions.
#
# Simulating net374...
# Done simulating net374 with 5 species and 5 reactions.
#
# Simulating net375...
# Done simulating net375 with 3 species and 1 reactions.
#
# Simulating net376...
# Done simulating net376 with 4 species and 2 reactions.
#
# Simulating net377...
# Done simulating net377 with 11 species and 9 reactions.
#
# Simulating net378...
# Done simulating net378 with 6 species and 4 reactions.
#
# Simulating net379...
# Done simulating net379 with 4 species and 2 reactions.
#
# Simulating net380...
# Done simulating net380 with 6 species and 4 reactions.
#
# Simulating net381...
# Done simulating net381 with 4 species and 2 reactions.
#
# Simulating net382...
# Done simulating net382 with 5 species and 3 reactions.
#
# Simulating net383...
# Done simulating net383 with 5 species and 3 reactions.
#
# Simulating net384...
# Done simulating net384 with 4 species and 2 reactions.
#
# Simulating net385...
# Done simulating net385 with 3 species and 1 reactions.
#
# Simulating net386...
# Done simulating net386 with 6 species and 4 reactions.
#
# Simulating net387...
# Done simulating net387 with 5 species and 3 reactions.
#
# Simulating net388...
# Done simulating net388 with 5 species and 4 reactions.
#
# Simulating net389...
# Done simulating net389 with 8 species and 6 reactions.
#
# Simulating net390...
# Done simulating net390 with 5 species and 3 reactions.
#
# Simulating net391...
# Done simulating net391 with 5 species and 4 reactions.
#
# Simulating net392...
# Done simulating net392 with 8 species and 6 reactions.
#
# Simulating net393...
# Done simulating net393 with 5 species and 3 reactions.
#
# Simulating net394...
# Done simulating net394 with 11 species and 9 reactions.
#
# Simulating net395...
# Done simulating net395 with 8 species and 5 reactions.
#
# Simulating net396...
# Done simulating net396 with 10 species and 7 reactions.
#
# Simulating net397...
# Done simulating net397 with 9 species and 7 reactions.
#
# Simulating net398...
# Done simulating net398 with 7 species and 5 reactions.
#
# Simulating net399...
# Done simulating net399 with 12 species and 9 reactions.
#
# Simulating net400...
# Done simulating net400 with 11 species and 9 reactions.
#
# Simulating net401...
# Done simulating net401 with 9 species and 7 reactions.
#
# Simulating net402...
# Done simulating net402 with 4 species and 2 reactions.
#
# Simulating net403...
# Done simulating net403 with 4 species and 2 reactions.
#
# Simulating net404...
# Done simulating net404 with 4 species and 2 reactions.
#
# Simulating net405...
# Done simulating net405 with 4 species and 2 reactions.
#
# Simulating net406...
# Done simulating net406 with 3 species and 2 reactions.
#
#
# Total elapsed time: 00 07:31:17
#
#
# ***
# All Done.
# ***

# %%
# Unite all networks into a single chemkin file
import re, string

#net=406

united = open('output/unitedChemkin.inp', 'w')
united.truncate(0)

original = open('input/chemkin.inp', 'r').readlines()

copy = True # copy the SPECIES and THERMO sections from the original file
lastline = ''
getlines = []
for line in original:
    if copy:
        getlines.append(line)
        if 'REACTIONS' in line: # copy the REACTIONS line, but then don't continue automaticaly
            copy = False
            getlines.append('\n')
    elif line[0] != '!' and 'END' not in line and line.count('+') == 3\
            and line.count('=') == 1 and line.count('+M') == 0: # copy only reactions which aren't unimolecular
        getlines.append(line)
        getlines.append('\n')
    elif "DUP" in line and lastline[0] != '!' and lastline.count('+') == 3\
            and lastline.count('=') == 1 and lastline.count('+M') == 0:
        getlines[-1] = line
        getlines.append('\n')
    lastline = line
united.writelines("%s" % str(item) for item in getlines)

for n in xrange(net):
    network = n + 1
    if network not in errored:
        f = open('runs/net'+str(network)+'/chemkin/chem_annotated.inp', 'r')
        species = False
        reactions = False
        #dictionary[] = {}
        dictionary['O2(2)'] = 'O2_2_(13)' # This is udapted per case
        comment = False # comment out using '!' reactions that contain 'CH4(1)'

        for line in f:
            if 'SPECIES' in line:
                species = True
            elif 'REACTIONS' in line:
                reactions = True
            elif 'END' in line:
                species = False
                reactions = False

            # make a dictionary of original species names (since RMG probably changed them)
            if species and 'SPECIES' not in line and 'CH4(1)' not in line and 'O2(2)' not in line:
                line=("".join(line.split())).split('!') # remove spaces and split at '!'
                if re.search('\(\d*\)$', line[1]) is not None:
                    dictionary[line[0]] = line[1][0:-len(re.search('\(\d*\)$', line[1]).group(0))]

            if reactions:
                for key in dictionary.keys():
                    line = string.replace(line,key,dictionary[key]) # replace species' names with dictionary names
                if 'CH4(1)' in line:
                    comment = True
                if line == '\n':
                    comment = False
                if comment:
                    line = '!' + line
                if 'REACTIONS' not in line:
                    united.writelines("%s" % line)
        f.close()
        
# still need to add all non-pdep
    
united.writelines("%s" % '\nEND')
united.close()

print("Saved PDep model into output directory.")
if len(errored) > 0:
    print("\n{0} networks resulted in an error:".format(len(errored)))
    for e in errored:
        print("ERROR in network {0}!".format(network))
# Out:
# Saved PDep model into output directory.
